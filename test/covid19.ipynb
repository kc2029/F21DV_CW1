# %%
import pandas as pd

# %%
geo = pd.read_json("/Users/kevinc/Library/Mobile Documents/com~apple~CloudDocs/custom.geo.json")

# %%
geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   type      175 non-null    object
#  1   features  175 non-null    object
# dtypes: object(2)
# memory usage: 2.9+ KB

# %%
cv = pd.read_csv("/Users/kevinc/Downloads/owid-covid-data.csv")

# %%
cv.head(10)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# 5      AFG      Asia  Afghanistan  2020-02-29          5.0        0.0
# 6      AFG      Asia  Afghanistan  2020-03-01          5.0        0.0
# 7      AFG      Asia  Afghanistan  2020-03-02          5.0        0.0
# 8      AFG      Asia  Afghanistan  2020-03-03          5.0        0.0
# 9      AFG      Asia  Afghanistan  2020-03-04          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# ...

# %%
cv["location"].value_counts()
# Out:
# Argentina         1142
# Mexico            1142
# Thailand          1139
# Taiwan            1127
# High income       1121
#                   ...
# Palau              543
# Tokelau            533
# Niue               485
# Pitcairn           441
# Western Sahara       1
# Name: location, Length: 248, dtype: int64

# %%
cv.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.432550e+05  2.429770e+05        2.417730e+05  2.235980e+05
# mean   5.270465e+06  1.181572e+04        1.186335e+04  7.972768e+04
# std    3.242531e+07  8.218288e+04        7.989583e+04  4.062786e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    5.708500e+03  0.000000e+00        4.571000e+00  1.240000e+02
# 50%    6.189000e+04  3.800000e+01        7.785700e+01  1.358000e+03
# 75%    6.402300e+05  8.260000e+02        1.006857e+03  1.097200e+04
# max    6.733467e+08  4.082888e+06        3.436560e+06  6.857274e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  223497.00000        222311.000000            242150.000000
# mean      127.48649           128.067274             73270.553171
# std       738.43841           684.531200            123801.009986
# min         0.00000             0.000000                 0.001000
# ...

# %%
a = cv.loc[cv["location"].isin(["Norway", "United Kingdom"]), ["iso_code","location", "date", "total_cases_per_million"]]
a
# Out:
#        iso_code        location        date  total_cases_per_million
# 173027      NOR          Norway  2020-02-12                      NaN
# 173028      NOR          Norway  2020-02-26                    0.184
# 173029      NOR          Norway  2020-02-27                    0.184
# 173030      NOR          Norway  2020-02-28                    1.104
# 173031      NOR          Norway  2020-02-29                    2.760
# ...         ...             ...         ...                      ...
# 242246      GBR  United Kingdom  2023-02-11               360189.101
# 242247      GBR  United Kingdom  2023-02-12               360189.101
# 242248      GBR  United Kingdom  2023-02-13               360189.101
# 242249      GBR  United Kingdom  2023-02-14               360189.101
# 242250      GBR  United Kingdom  2023-02-15               360189.101
#
# [2200 rows x 4 columns]

# %%
a.to_csv("/Users/kevinc/Downloads/F21DV/CW1/F21DV_CW1/data/test3.csv", index=False)
